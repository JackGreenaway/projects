# %%
import MeanReversion as mr

# %%
m_rev = mr.mean_reversion_bt('AAPL', '2018-12-31')

print('------   RESULTS   -----')
print(f'Strategy: {round(m_rev.cum_profit,4)*100}%\nBuy/hold: {round(m_rev.buyHold,4)*100}%\nDifference: {round(m_rev.cum_profit-m_rev.buyHold,4)*100}%\n')

m_rev.current_signal()
#m_rev.trade_breakdown()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ------   RESULTS   -----
# Strategy: -0.73%
# Buy/hold: 307.03999999999996%
# Difference: -307.76%
#
# Current signal as of 2023-02-08 00:00:00-05:00:
#
# Sell

# %%
m_rev.plot_bands()

# %%
m_rev.df.tail(10)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-26 00:00:00-05:00  143.169998  144.250000  141.899994  143.960007
# 2023-01-27 00:00:00-05:00  143.160004  147.229996  143.080002  145.929993
# 2023-01-30 00:00:00-05:00  144.960007  145.550003  142.850006  143.000000
# 2023-01-31 00:00:00-05:00  142.699997  144.339996  142.279999  144.289993
# 2023-02-01 00:00:00-05:00  143.970001  146.610001  141.320007  145.429993
# 2023-02-02 00:00:00-05:00  148.899994  151.179993  148.169998  150.820007
# 2023-02-03 00:00:00-05:00  148.029999  157.380005  147.830002  154.500000
# 2023-02-06 00:00:00-05:00  152.570007  153.100006  150.779999  151.729996
# 2023-02-07 00:00:00-05:00  150.639999  155.229996  150.639999  154.649994
# 2023-02-08 00:00:00-05:00  153.880005  154.580002  151.169998  151.919998
#
#                             Adj Close     Volume    HighBand  MiddleBand  \
# Date
# ...
